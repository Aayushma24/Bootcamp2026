# %%
s = input("Enter the string: ")
flag = True

for i in range(0, len(s)//2):
    if s[i] != s[len(s)-i-1]:
        flag = False
        break

if flag:
    print("Palindrome")
else:
    print("Not a palindrome")
# Out:
# Enter the string:  abba
# Not a palindrome

# %%
#function in python
def multiply(*salman):
  product=1
  for i in salman:
    product=product *i
  print(salman)
  return product

# %%
multiply(1,2,3,4,5)
# Out:
# (1, 2, 3, 4, 5)
# 120
