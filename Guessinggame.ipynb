# %%
import random as r
x=r.randint(1,100)
print("Enter the guessing number....")
a=int(input("Enter the number"))
if(x==a):
    
    print("You are successfully guess the correct number")
else:
    print("Oops,better luck next time")
print(f"The guessing number is {x}")
# Out:
# Enter the guessing number....
# Enter the number 56
# Oops,better luck next time
# The guessing number is 19

# %%
#Even and odd number
num=int(input("Enter the number"))
if num%2==0:
    print("The number is even")
        
else:
    print("The number is odd")
# Out:
# Enter the number 45
# The number is odd

# %%
#Prime and Composite number
num=int(input("Enter the number"))
if num <= 1:
    print("neither composite nor prime")
else:
    for i in range(2,num):
        if num% i ==0:
            print("Composite number")
            break
        else:
            print("Prime number")
            break
# Out:
# Enter the number 0
# neither composite nor prime

# %%
#palindrome
def palindrome(num):
 if num==num[::-1]:
    print("The number is palindrome")
 else:
   print("The number is not palindrome")
x=(input("Enter a number or name"))
palindrome(x)
# Out:
# Enter a number or name radar
# The number is palindrome
